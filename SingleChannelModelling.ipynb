# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install yt-dlp opencv-python-headless deepface google-api-python-client
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.3.31-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.164.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (2.0.2)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.32.3)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (11.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from deepface) (4.11.0.86)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.18.0)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (3.8.0)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from deepface) (3.1.0)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.4.0->deepface) (3.0.1)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=3.10.1->deepface) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.4.1)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (2025.1.31)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=1.9.0->deepface) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=2.2.0->deepface) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Downloading yt_dlp-2025.3.31-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 87.4 MB/s eta 0:00:00
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 10.1 MB/s eta 0:00:00
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.3 MB/s eta 0:00:00
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 78.0 MB/s eta 0:00:00
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.2 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=f9f06dd02859634ab11ee8d9bb256725ec99581e96a082a108d235b94a94736d
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: yt-dlp, lz4, gunicorn, fire, mtcnn, flask-cors, retina-face, deepface
# Successfully installed deepface-0.0.93 fire-0.7.0 flask-cors-5.0.1 gunicorn-23.0.0 lz4-4.4.4 mtcnn-1.0.0 retina-face-0.0.17 yt-dlp-2025.3.31

# %%
import os
import cv2
import yt_dlp
import requests
import time
import pandas as pd
from deepface import DeepFace
from googleapiclient.discovery import build
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta, timezone

# %%
PROJECT_ROOT = Path("Data")
VIDEO_DIR = PROJECT_ROOT / "videos"
FRAME_DIR = PROJECT_ROOT / "frames"
META_DIR = PROJECT_ROOT / "metadata"
RESULT_DIR = PROJECT_ROOT / "results"
PLAYLIST_DIR = PROJECT_ROOT / "playlists"

# Ensure folders exist
for folder in [VIDEO_DIR, FRAME_DIR, META_DIR, RESULT_DIR, PLAYLIST_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

# %%
API_KEY = 'AIzaSyC34PDdHRGHIYIT_iqEquq9na1JHgOhMSY'
youtube = build('youtube', 'v3', developerKey=API_KEY)

# %% [markdown]
# # Get the Playlist of Selected Channel

# %% [markdown]
# ## Find Channel ID

# %%
channel_name = "Casey Neistat" # change here to search for other channel

search_response = youtube.search().list(
    part="snippet",
    q=channel_name,
    type="channel",
    maxResults=1
).execute()

channel_id = search_response['items'][0]['snippet']['channelId']
channel_title = search_response['items'][0]['snippet']['title']
print(f"✅ Found channel: {channel_title} (ID: {channel_id})")
# Out:
# ✅ Found channel: CaseyNeistat (ID: UCtinbF-Q-fVthA0qrFQTgXQ)

# %% [markdown]
# ## Retrive All Video List From A Specific Channel

# %%
# Step 1: Get the channel's uploads playlist ID
channel_response = youtube.channels().list(
    part="contentDetails",
    id=channel_id
).execute()

uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Step 2: Loop through the uploads playlist to get all videos
all_videos = []
next_page_token = None

while True:
    playlist_response = youtube.playlistItems().list(
        part="snippet",
        playlistId=uploads_playlist_id,
        maxResults=50,
        pageToken=next_page_token
    ).execute()

    for item in playlist_response['items']:
        snippet = item['snippet']
        video_id = snippet['resourceId']['videoId']
        title = snippet['title']
        published_at = snippet['publishedAt']

        all_videos.append({
            "video_id": video_id,
            "video_title": title,
            "published_at": published_at,
            "playlist_name": "Uploads",  # Optional label
            "playlist_id": uploads_playlist_id,
            "video_url": f"https://www.youtube.com/watch?v={video_id}"
        })

    next_page_token = playlist_response.get('nextPageToken')
    if not next_page_token:
        break

    time.sleep(0.5)  # Be kind to the API

# %% [markdown]
# ## Get Video-level Metadata

# %%
videos_with_stats = []

video_id_list = [v['video_id'] for v in all_videos]

for i in tqdm(range(0, len(video_id_list), 50), desc="Fetching video stats"):
    batch_ids = video_id_list[i:i+50]
    stats_response = youtube.videos().list(
        part="snippet,statistics,contentDetails",
        id=",".join(batch_ids)
    ).execute()

    video_stats_map = {item["id"]: item for item in stats_response["items"]}

    for video in all_videos[i:i+50]:
        video_id = video["video_id"]
        video_data = video_stats_map.get(video_id)

        if video_data:
            snippet = video_data["snippet"]
            stats = video_data.get("statistics", {})
            content = video_data.get("contentDetails", {})

            video.update({
                "channel_title": snippet.get("channelTitle"),
                "views": int(stats.get("viewCount", 0)),
                "likes": int(stats.get("likeCount", 0)),
                "comments": int(stats.get("commentCount", 0)),
                "duration": content.get("duration")
            })

            videos_with_stats.append(video)

    time.sleep(1)
# Out:
# Fetching video stats: 100%|██████████| 23/23 [00:27<00:00,  1.17s/it]

# %%
df = pd.DataFrame(videos_with_stats)
df = df.drop_duplicates(subset="video_id", keep="first")

# Sanitize channel title to make it filename-safe (optional but recommended)
safe_channel_title = channel_title.replace(" ", "_").replace("/", "_")

# Define output path inside the playlists directory
playlist_stats_path = PLAYLIST_DIR / f"{safe_channel_title}_playlists_with_stats.csv"
# Save the DataFrame
df.to_csv(playlist_stats_path, index=False)

print(df.head())
print(f"✅ Total unique videos for {channel_title}: {len(df)}")
# Out:
#       video_id                                        video_title  \
# 0  Ud2BcD5NC2A                              The IMPOSSIBLE Camera
# 1  AjKGToaFDvA           the very WORST Nintendo Switch 2 review.
# 2  StMltAX0mp0                                     DO HARD THINGS
# 3  TUbIKg-lrow  New York City's Controversial Fire Hydrant Fis...
# 4  h-vWRLGnTGg  the importance of picking a fight you'll never...
#
#            published_at playlist_name               playlist_id  \
# 0  2025-04-22T12:21:40Z       Uploads  UUtinbF-Q-fVthA0qrFQTgXQ
# 1  2025-04-04T17:30:56Z       Uploads  UUtinbF-Q-fVthA0qrFQTgXQ
# 2  2024-11-14T18:49:01Z       Uploads  UUtinbF-Q-fVthA0qrFQTgXQ
# 3  2024-09-23T15:29:37Z       Uploads  UUtinbF-Q-fVthA0qrFQTgXQ
# 4  2024-03-20T20:10:44Z       Uploads  UUtinbF-Q-fVthA0qrFQTgXQ
#
#                                      video_url channel_title    views   likes  \
# 0  https://www.youtube.com/watch?v=Ud2BcD5NC2A  CaseyNeistat  1095921   58822
# 1  https://www.youtube.com/watch?v=AjKGToaFDvA  CaseyNeistat  1141332   46962
# 2  https://www.youtube.com/watch?v=StMltAX0mp0  CaseyNeistat  3028363  143023
# 3  https://www.youtube.com/watch?v=TUbIKg-lrow  CaseyNeistat  1978684   79441
# 4  https://www.youtube.com/watch?v=h-vWRLGnTGg  CaseyNeistat  2011737   72894
#
#    comments  duration
# 0      2663  PT10M42S
# 1      2218   PT6M30S
# 2      4893  PT12M37S
# 3      4103      PT7M
# 4      3786   PT12M9S
# ✅ Total unique videos for CaseyNeistat: 1115

# %% [markdown]
# ## Video From 2020

# %%
PLAYLIST_DIR = Path("Data/playlists")
filename = "CaseyNeistat_playlists_with_stats.csv"
playlist_stats_path = PLAYLIST_DIR / filename
df = pd.read_csv(playlist_stats_path)

# Parse published_at column to datetime with UTC
df['published_at'] = pd.to_datetime(df['published_at'], utc=True)

# Filter videos where year >= 2020
df_from_2020 = df[df['published_at'].dt.year >= 2020]

# Extract video URLs
video_urls = df_from_2020['video_url'].tolist()

# Confirm
print(f"✅ Found {len(df_from_2020)} videos published after 2020")
print(df_from_2020[['video_title', 'published_at']].head())
# Out:
# ✅ Found 90 videos published after 2020
#                                          video_title              published_at
# 0                              The IMPOSSIBLE Camera 2025-04-22 12:21:40+00:00
# 1           the very WORST Nintendo Switch 2 review. 2025-04-04 17:30:56+00:00
# 2                                     DO HARD THINGS 2024-11-14 18:49:01+00:00
# 3  New York City's Controversial Fire Hydrant Fis... 2024-09-23 15:29:37+00:00
# 4  the importance of picking a fight you'll never... 2024-03-20 20:10:44+00:00

# %% [markdown]
# # Video Processing

# %% [markdown]
# ## Video Download

# %%
ydl_opts = {
    'format': 'best[ext=mp4]',
    'outtmpl': str(VIDEO_DIR / '%(id)s.%(ext)s'),
    'noplaylist': True,
    'quiet': False
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download(video_urls)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ud2BcD5NC2A
# [youtube] Ud2BcD5NC2A: Downloading webpage
# [youtube] Ud2BcD5NC2A: Downloading tv client config
# [youtube] Ud2BcD5NC2A: Downloading player aa3fc80b-main
# [youtube] Ud2BcD5NC2A: Downloading tv player API JSON
# [youtube] Ud2BcD5NC2A: Downloading ios player API JSON
# [youtube] Ud2BcD5NC2A: Downloading m3u8 information
# [info] Ud2BcD5NC2A: Downloading 1 format(s): 18
# [download] Destination: Data/videos/Ud2BcD5NC2A.mp4
# [download] 100% of   46.11MiB in 00:00:08 at 5.14MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AjKGToaFDvA
# [youtube] AjKGToaFDvA: Downloading webpage
# [youtube] AjKGToaFDvA: Downloading tv client config
# [youtube] AjKGToaFDvA: Downloading tv player API JSON
# [youtube] AjKGToaFDvA: Downloading ios player API JSON
# [youtube] AjKGToaFDvA: Downloading m3u8 information
# [info] AjKGToaFDvA: Downloading 1 format(s): 18
# [download] Destination: Data/videos/AjKGToaFDvA.mp4
# [download] 100% of   33.06MiB in 00:00:08 at 4.10MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=StMltAX0mp0
# [youtube] StMltAX0mp0: Downloading webpage
# [youtube] StMltAX0mp0: Downloading tv client config
# [youtube] StMltAX0mp0: Downloading tv player API JSON
# [youtube] StMltAX0mp0: Downloading ios player API JSON
# [youtube] StMltAX0mp0: Downloading m3u8 information
# [info] StMltAX0mp0: Downloading 1 format(s): 18
# [download] Destination: Data/videos/StMltAX0mp0.mp4
# [download] 100% of   54.89MiB in 00:00:12 at 4.52MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TUbIKg-lrow
# [youtube] TUbIKg-lrow: Downloading webpage
# [youtube] TUbIKg-lrow: Downloading tv client config
# [youtube] TUbIKg-lrow: Downloading tv player API JSON
# [youtube] TUbIKg-lrow: Downloading ios player API JSON
# [youtube] TUbIKg-lrow: Downloading m3u8 information
# [info] TUbIKg-lrow: Downloading 1 format(s): 18
# [download] Destination: Data/videos/TUbIKg-lrow.mp4
# [download] 100% of   31.64MiB in 00:00:07 at 4.50MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h-vWRLGnTGg
# [youtube] h-vWRLGnTGg: Downloading webpage
# [youtube] h-vWRLGnTGg: Downloading tv client config
# [youtube] h-vWRLGnTGg: Downloading tv player API JSON
# [youtube] h-vWRLGnTGg: Downloading ios player API JSON
# [youtube] h-vWRLGnTGg: Downloading m3u8 information
# [info] h-vWRLGnTGg: Downloading 1 format(s): 18
# [download] Destination: Data/videos/h-vWRLGnTGg.mp4
# [download] 100% of   35.66MiB in 00:00:07 at 4.47MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9IiTdSnmS7E
# [youtube] 9IiTdSnmS7E: Downloading webpage
# [youtube] 9IiTdSnmS7E: Downloading tv client config
# [youtube] 9IiTdSnmS7E: Downloading tv player API JSON
# [youtube] 9IiTdSnmS7E: Downloading ios player API JSON
# [youtube] 9IiTdSnmS7E: Downloading m3u8 information
# [info] 9IiTdSnmS7E: Downloading 1 format(s): 18
# [download] Destination: Data/videos/9IiTdSnmS7E.mp4
# [download] 100% of   38.55MiB in 00:00:12 at 2.97MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UvkgmyfMPks
# [youtube] UvkgmyfMPks: Downloading webpage
# [youtube] UvkgmyfMPks: Downloading tv client config
# [youtube] UvkgmyfMPks: Downloading tv player API JSON
# [youtube] UvkgmyfMPks: Downloading ios player API JSON
# [youtube] UvkgmyfMPks: Downloading m3u8 information
# [info] UvkgmyfMPks: Downloading 1 format(s): 18
# [download] Destination: Data/videos/UvkgmyfMPks.mp4
# [download] 100% of   34.53MiB in 00:00:07 at 4.43MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lI_3AiV0CnI
# [youtube] lI_3AiV0CnI: Downloading webpage
# [youtube] lI_3AiV0CnI: Downloading tv client config
# [youtube] lI_3AiV0CnI: Downloading tv player API JSON
# [youtube] lI_3AiV0CnI: Downloading ios player API JSON
# [youtube] lI_3AiV0CnI: Downloading m3u8 information
# [info] lI_3AiV0CnI: Downloading 1 format(s): 18
# [download] Destination: Data/videos/lI_3AiV0CnI.mp4
# [download] 100% of   41.28MiB in 00:00:08 at 4.63MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o2C35kWHPAA
# [youtube] o2C35kWHPAA: Downloading webpage
# [youtube] o2C35kWHPAA: Downloading tv client config
# [youtube] o2C35kWHPAA: Downloading tv player API JSON
# [youtube] o2C35kWHPAA: Downloading ios player API JSON
# [youtube] o2C35kWHPAA: Downloading m3u8 information
# [info] o2C35kWHPAA: Downloading 1 format(s): 18
# [download] Destination: Data/videos/o2C35kWHPAA.mp4
# [download] 100% of   46.08MiB in 00:00:10 at 4.39MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JFKJYE3LcYk
# [youtube] JFKJYE3LcYk: Downloading webpage
# [youtube] JFKJYE3LcYk: Downloading tv client config
# [youtube] JFKJYE3LcYk: Downloading tv player API JSON
# [youtube] JFKJYE3LcYk: Downloading ios player API JSON
# [youtube] JFKJYE3LcYk: Downloading m3u8 information
# [info] JFKJYE3LcYk: Downloading 1 format(s): 18
# [download] Destination: Data/videos/JFKJYE3LcYk.mp4
# [download] 100% of    4.27MiB in 00:00:01 at 2.73MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kVHGhdUDjPU
# [youtube] kVHGhdUDjPU: Downloading webpage
# [youtube] kVHGhdUDjPU: Downloading tv client config
# [youtube] kVHGhdUDjPU: Downloading tv player API JSON
# [youtube] kVHGhdUDjPU: Downloading ios player API JSON
# [youtube] kVHGhdUDjPU: Downloading m3u8 information
# [info] kVHGhdUDjPU: Downloading 1 format(s): 18
# [download] Destination: Data/videos/kVHGhdUDjPU.mp4
# [download] 100% of   23.84MiB in 00:00:06 at 3.95MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DpJzOuYSpKo
# [youtube] DpJzOuYSpKo: Downloading webpage
# [youtube] DpJzOuYSpKo: Downloading tv client config
# [youtube] DpJzOuYSpKo: Downloading tv player API JSON
# [youtube] DpJzOuYSpKo: Downloading ios player API JSON
# [youtube] DpJzOuYSpKo: Downloading m3u8 information
# [info] DpJzOuYSpKo: Downloading 1 format(s): 18
# [download] Destination: Data/videos/DpJzOuYSpKo.mp4
# [download] 100% of   21.13MiB in 00:00:04 at 4.52MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BZEr7_Oggcw
# [youtube] BZEr7_Oggcw: Downloading webpage
# [youtube] BZEr7_Oggcw: Downloading tv client config
# [youtube] BZEr7_Oggcw: Downloading tv player API JSON
# [youtube] BZEr7_Oggcw: Downloading ios player API JSON
# [youtube] BZEr7_Oggcw: Downloading m3u8 information
# [info] BZEr7_Oggcw: Downloading 1 format(s): 18
# [download] Destination: Data/videos/BZEr7_Oggcw.mp4
# [download] 100% of   23.42MiB in 00:00:06 at 3.84MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LgKulg2YVZo
# [youtube] LgKulg2YVZo: Downloading webpage
# [youtube] LgKulg2YVZo: Downloading tv client config
# [youtube] LgKulg2YVZo: Downloading tv player API JSON
# [youtube] LgKulg2YVZo: Downloading ios player API JSON
# [youtube] LgKulg2YVZo: Downloading m3u8 information
# [info] LgKulg2YVZo: Downloading 1 format(s): 18
# [download] Destination: Data/videos/LgKulg2YVZo.mp4
# [download] 100% of    1.57MiB in 00:00:01 at 1.45MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0TvLl2f0wC8
# [youtube] 0TvLl2f0wC8: Downloading webpage
# [youtube] 0TvLl2f0wC8: Downloading tv client config
# [youtube] 0TvLl2f0wC8: Downloading tv player API JSON
# [youtube] 0TvLl2f0wC8: Downloading ios player API JSON
# [youtube] 0TvLl2f0wC8: Downloading m3u8 information
# [info] 0TvLl2f0wC8: Downloading 1 format(s): 18
# [download] Destination: Data/videos/0TvLl2f0wC8.mp4
# [download] 100% of   28.51MiB in 00:00:06 at 4.32MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Cm_uIxcczWM
# [youtube] Cm_uIxcczWM: Downloading webpage
# [youtube] Cm_uIxcczWM: Downloading tv client config
# [youtube] Cm_uIxcczWM: Downloading tv player API JSON
# [youtube] Cm_uIxcczWM: Downloading ios player API JSON
# [youtube] Cm_uIxcczWM: Downloading m3u8 information
# [info] Cm_uIxcczWM: Downloading 1 format(s): 18
# [download] Destination: Data/videos/Cm_uIxcczWM.mp4
# [download] 100% of   33.20MiB in 00:00:08 at 4.11MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UVX6kxnJgMU
# [youtube] UVX6kxnJgMU: Downloading webpage
# [youtube] UVX6kxnJgMU: Downloading tv client config
# [youtube] UVX6kxnJgMU: Downloading tv player API JSON
# [youtube] UVX6kxnJgMU: Downloading ios player API JSON
# [youtube] UVX6kxnJgMU: Downloading m3u8 information
# [info] UVX6kxnJgMU: Downloading 1 format(s): 18
# [download] Destination: Data/videos/UVX6kxnJgMU.mp4
# [download] 100% of    8.43MiB in 00:00:03 at 2.56MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h9xaHwBsRUw
# [youtube] h9xaHwBsRUw: Downloading webpage
# [youtube] h9xaHwBsRUw: Downloading tv client config
# [youtube] h9xaHwBsRUw: Downloading tv player API JSON
# [youtube] h9xaHwBsRUw: Downloading ios player API JSON
# [youtube] h9xaHwBsRUw: Downloading m3u8 information
# [info] h9xaHwBsRUw: Downloading 1 format(s): 18
# [download] Destination: Data/videos/h9xaHwBsRUw.mp4
# [download] 100% of   11.28MiB in 00:00:03 at 3.46MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YpqFOB7_9go
# [youtube] YpqFOB7_9go: Downloading webpage
# [youtube] YpqFOB7_9go: Downloading tv client config
# [youtube] YpqFOB7_9go: Downloading tv player API JSON
# [youtube] YpqFOB7_9go: Downloading ios player API JSON
# [youtube] YpqFOB7_9go: Downloading m3u8 information
# [info] YpqFOB7_9go: Downloading 1 format(s): 18
# [download] Destination: Data/videos/YpqFOB7_9go.mp4
# [download] 100% of   32.41MiB in 00:00:08 at 3.81MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ygj9vBF_WUk
# [youtube] Ygj9vBF_WUk: Downloading webpage
# [youtube] Ygj9vBF_WUk: Downloading tv client config
# [youtube] Ygj9vBF_WUk: Downloading tv player API JSON
# [youtube] Ygj9vBF_WUk: Downloading ios player API JSON
# [youtube] Ygj9vBF_WUk: Downloading m3u8 information
# [info] Ygj9vBF_WUk: Downloading 1 format(s): 18
# [download] Destination: Data/videos/Ygj9vBF_WUk.mp4
# [download] 100% of   15.36MiB in 00:00:07 at 2.03MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3CJZli1VFQg
# [youtube] 3CJZli1VFQg: Downloading webpage
# [youtube] 3CJZli1VFQg: Downloading tv client config
# [youtube] 3CJZli1VFQg: Downloading tv player API JSON
# [youtube] 3CJZli1VFQg: Downloading ios player API JSON
# [youtube] 3CJZli1VFQg: Downloading m3u8 information
# [info] 3CJZli1VFQg: Downloading 1 format(s): 18
# [download] Destination: Data/videos/3CJZli1VFQg.mp4
# [download] 100% of   31.90MiB in 00:00:09 at 3.35MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=34k7UI-DR_8
# [youtube] 34k7UI-DR_8: Downloading webpage
# [youtube] 34k7UI-DR_8: Downloading tv client config
# [youtube] 34k7UI-DR_8: Downloading tv player API JSON
# [youtube] 34k7UI-DR_8: Downloading ios player API JSON
# [youtube] 34k7UI-DR_8: Downloading m3u8 information
# [info] 34k7UI-DR_8: Downloading 1 format(s): 18
# [download] Destination: Data/videos/34k7UI-DR_8.mp4
# [download] 100% of   17.37MiB in 00:00:04 at 3.62MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ouPPSqFAbb4
# [youtube] ouPPSqFAbb4: Downloading webpage
# [youtube] ouPPSqFAbb4: Downloading tv client config
# [youtube] ouPPSqFAbb4: Downloading tv player API JSON
# [youtube] ouPPSqFAbb4: Downloading ios player API JSON
# [youtube] ouPPSqFAbb4: Downloading m3u8 information
# [info] ouPPSqFAbb4: Downloading 1 format(s): 18
# [download] Destination: Data/videos/ouPPSqFAbb4.mp4
# [download] 100% of   16.06MiB in 00:00:05 at 3.10MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rzCFZypafAM
# [youtube] rzCFZypafAM: Downloading webpage
# [youtube] rzCFZypafAM: Downloading tv client config
# [youtube] rzCFZypafAM: Downloading tv player API JSON
# [youtube] rzCFZypafAM: Downloading ios player API JSON
# [youtube] rzCFZypafAM: Downloading m3u8 information
# [info] rzCFZypafAM: Downloading 1 format(s): 18
# [download] Destination: Data/videos/rzCFZypafAM.mp4
# [download] 100% of   22.64MiB in 00:00:08 at 2.53MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WlY9pDwGbjw
# [youtube] WlY9pDwGbjw: Downloading webpage
# [youtube] WlY9pDwGbjw: Downloading tv client config
# [youtube] WlY9pDwGbjw: Downloading tv player API JSON
# [youtube] WlY9pDwGbjw: Downloading ios player API JSON
# [youtube] WlY9pDwGbjw: Downloading m3u8 information
# [info] WlY9pDwGbjw: Downloading 1 format(s): 18
# [download] Destination: Data/videos/WlY9pDwGbjw.mp4
# [download] 100% of   23.55MiB in 00:00:06 at 3.63MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o0xoWsYXIrY
# [youtube] o0xoWsYXIrY: Downloading webpage
# [youtube] o0xoWsYXIrY: Downloading tv client config
# [youtube] o0xoWsYXIrY: Downloading tv player API JSON
# [youtube] o0xoWsYXIrY: Downloading ios player API JSON
# [youtube] o0xoWsYXIrY: Downloading m3u8 information
# [info] o0xoWsYXIrY: Downloading 1 format(s): 18
# [download] Destination: Data/videos/o0xoWsYXIrY.mp4
# [download] 100% of    1.84MiB in 00:00:00 at 1.85MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cldSbEoNR2A
# [youtube] cldSbEoNR2A: Downloading webpage
# [youtube] cldSbEoNR2A: Downloading tv client config
# [youtube] cldSbEoNR2A: Downloading tv player API JSON
# [youtube] cldSbEoNR2A: Downloading ios player API JSON
# [youtube] cldSbEoNR2A: Downloading m3u8 information
# [info] cldSbEoNR2A: Downloading 1 format(s): 18
# [download] Destination: Data/videos/cldSbEoNR2A.mp4
# [download] 100% of    4.13MiB in 00:00:01 at 2.72MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KehujfbRBts
# [youtube] KehujfbRBts: Downloading webpage
# [youtube] KehujfbRBts: Downloading tv client config
# [youtube] KehujfbRBts: Downloading tv player API JSON
# [youtube] KehujfbRBts: Downloading ios player API JSON
# [youtube] KehujfbRBts: Downloading m3u8 information
# [info] KehujfbRBts: Downloading 1 format(s): 18
# [download] Destination: Data/videos/KehujfbRBts.mp4
# [download] 100% of   29.87MiB in 00:00:08 at 3.62MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=i4GJnpOZmiM
# [youtube] i4GJnpOZmiM: Downloading webpage
# [youtube] i4GJnpOZmiM: Downloading tv client config
# [youtube] i4GJnpOZmiM: Downloading tv player API JSON
# [youtube] i4GJnpOZmiM: Downloading ios player API JSON
# [youtube] i4GJnpOZmiM: Downloading m3u8 information
# [info] i4GJnpOZmiM: Downloading 1 format(s): 18
# [download] Destination: Data/videos/i4GJnpOZmiM.mp4
# [download] 100% of    5.73MiB in 00:00:02 at 2.28MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mshN3N0jOng
# [youtube] mshN3N0jOng: Downloading webpage
# [youtube] mshN3N0jOng: Downloading tv client config
# [youtube] mshN3N0jOng: Downloading tv player API JSON
# [youtube] mshN3N0jOng: Downloading ios player API JSON
# [youtube] mshN3N0jOng: Downloading m3u8 information
# [info] mshN3N0jOng: Downloading 1 format(s): 18
# [download] Destination: Data/videos/mshN3N0jOng.mp4
# [download] 100% of   50.48MiB in 00:00:13 at 3.64MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Qwr5tGG0jfQ
# [youtube] Qwr5tGG0jfQ: Downloading webpage
# [youtube] Qwr5tGG0jfQ: Downloading tv client config
# [youtube] Qwr5tGG0jfQ: Downloading tv player API JSON
# [youtube] Qwr5tGG0jfQ: Downloading ios player API JSON
# [youtube] Qwr5tGG0jfQ: Downloading m3u8 information
# [info] Qwr5tGG0jfQ: Downloading 1 format(s): 18
# [download] Destination: Data/videos/Qwr5tGG0jfQ.mp4
# [download] 100% of   21.63MiB in 00:00:06 at 3.17MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7lGLhhoIsNc
# [youtube] 7lGLhhoIsNc: Downloading webpage
# [youtube] 7lGLhhoIsNc: Downloading tv client config
# [youtube] 7lGLhhoIsNc: Downloading tv player API JSON
# [youtube] 7lGLhhoIsNc: Downloading ios player API JSON
# [youtube] 7lGLhhoIsNc: Downloading m3u8 information
# [info] 7lGLhhoIsNc: Downloading 1 format(s): 18
# [download] Destination: Data/videos/7lGLhhoIsNc.mp4
# [download] 100% of   50.07MiB in 00:00:12 at 4.08MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YbE_FD8df80
# [youtube] YbE_FD8df80: Downloading webpage
# [youtube] YbE_FD8df80: Downloading tv client config
# [youtube] YbE_FD8df80: Downloading tv player API JSON
# [youtube] YbE_FD8df80: Downloading ios player API JSON
# [youtube] YbE_FD8df80: Downloading m3u8 information
# [info] YbE_FD8df80: Downloading 1 format(s): 18
# [download] Destination: Data/videos/YbE_FD8df80.mp4
# [download] 100% of    2.71MiB in 00:00:01 at 2.54MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bEriqRN7Xpg
# [youtube] bEriqRN7Xpg: Downloading webpage
# [youtube] bEriqRN7Xpg: Downloading tv client config
# [youtube] bEriqRN7Xpg: Downloading tv player API JSON
# [youtube] bEriqRN7Xpg: Downloading ios player API JSON
# [youtube] bEriqRN7Xpg: Downloading m3u8 information
# [info] bEriqRN7Xpg: Downloading 1 format(s): 18
# [download] Destination: Data/videos/bEriqRN7Xpg.mp4
# [download] 100% of   25.76MiB in 00:00:06 at 3.81MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LODwfHdZA_k
# [youtube] LODwfHdZA_k: Downloading webpage
# [youtube] LODwfHdZA_k: Downloading tv client config
# [youtube] LODwfHdZA_k: Downloading tv player API JSON
# [youtube] LODwfHdZA_k: Downloading ios player API JSON
# [youtube] LODwfHdZA_k: Downloading m3u8 information
# [info] LODwfHdZA_k: Downloading 1 format(s): 18
# [download] Destination: Data/videos/LODwfHdZA_k.mp4
# [download] 100% of   19.32MiB in 00:00:08 at 2.32MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kvnn_EptPiQ
# [youtube] kvnn_EptPiQ: Downloading webpage
# [youtube] kvnn_EptPiQ: Downloading tv client config
# [youtube] kvnn_EptPiQ: Downloading tv player API JSON
# [youtube] kvnn_EptPiQ: Downloading ios player API JSON
# [youtube] kvnn_EptPiQ: Downloading m3u8 information
# [info] kvnn_EptPiQ: Downloading 1 format(s): 18
# [download] Destination: Data/videos/kvnn_EptPiQ.mp4
# [download] 100% of   31.25MiB in 00:00:07 at 4.00MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2MQF00rTEJU
# [youtube] 2MQF00rTEJU: Downloading webpage
# [youtube] 2MQF00rTEJU: Downloading tv client config
# [youtube] 2MQF00rTEJU: Downloading tv player API JSON
# [youtube] 2MQF00rTEJU: Downloading ios player API JSON
# [youtube] 2MQF00rTEJU: Downloading m3u8 information
# [info] 2MQF00rTEJU: Downloading 1 format(s): 18
# [download] Destination: Data/videos/2MQF00rTEJU.mp4
# [download] 100% of   36.14MiB in 00:00:17 at 2.11MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NK45KHO5ng0
# [youtube] NK45KHO5ng0: Downloading webpage
# [youtube] NK45KHO5ng0: Downloading tv client config
# [youtube] NK45KHO5ng0: Downloading tv player API JSON
# [youtube] NK45KHO5ng0: Downloading ios player API JSON
# [youtube] NK45KHO5ng0: Downloading m3u8 information
# [info] NK45KHO5ng0: Downloading 1 format(s): 18
# [download] Destination: Data/videos/NK45KHO5ng0.mp4
# [download] 100% of   50.65MiB in 00:00:38 at 1.31MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6ksZoza2Fhc
# [youtube] 6ksZoza2Fhc: Downloading webpage
# [youtube] 6ksZoza2Fhc: Downloading tv client config
# [youtube] 6ksZoza2Fhc: Downloading tv player API JSON
# [youtube] 6ksZoza2Fhc: Downloading ios player API JSON
# [youtube] 6ksZoza2Fhc: Downloading m3u8 information
# [info] 6ksZoza2Fhc: Downloading 1 format(s): 18
# [download] Destination: Data/videos/6ksZoza2Fhc.mp4
# [download] 100% of   21.14MiB in 00:00:05 at 4.08MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fIdRWKel0xQ
# [youtube] fIdRWKel0xQ: Downloading webpage
# [youtube] fIdRWKel0xQ: Downloading tv client config
# [youtube] fIdRWKel0xQ: Downloading tv player API JSON
# [youtube] fIdRWKel0xQ: Downloading ios player API JSON
# [youtube] fIdRWKel0xQ: Downloading m3u8 information
# [info] fIdRWKel0xQ: Downloading 1 format(s): 18
# [download] Destination: Data/videos/fIdRWKel0xQ.mp4
# [download] 100% of   25.72MiB in 00:00:06 at 4.03MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C3P-b5Szz44
# [youtube] C3P-b5Szz44: Downloading webpage
# [youtube] C3P-b5Szz44: Downloading tv client config
# [youtube] C3P-b5Szz44: Downloading tv player API JSON
# [youtube] C3P-b5Szz44: Downloading ios player API JSON
# [youtube] C3P-b5Szz44: Downloading m3u8 information
# [info] C3P-b5Szz44: Downloading 1 format(s): 18
# [download] Destination: Data/videos/C3P-b5Szz44.mp4
# [download] 100% of   22.62MiB in 00:00:05 at 4.04MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l30V426-_S4
# [youtube] l30V426-_S4: Downloading webpage
# [youtube] l30V426-_S4: Downloading tv client config
# [youtube] l30V426-_S4: Downloading tv player API JSON
# [youtube] l30V426-_S4: Downloading ios player API JSON
# [youtube] l30V426-_S4: Downloading m3u8 information
# [info] l30V426-_S4: Downloading 1 format(s): 18
# [download] Destination: Data/videos/l30V426-_S4.mp4
# [download] 100% of   40.17MiB in 00:00:08 at 4.68MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X16jagQdNIE
# [youtube] X16jagQdNIE: Downloading webpage
# [youtube] X16jagQdNIE: Downloading tv client config
# [youtube] X16jagQdNIE: Downloading tv player API JSON
# [youtube] X16jagQdNIE: Downloading ios player API JSON
# [youtube] X16jagQdNIE: Downloading m3u8 information
# [info] X16jagQdNIE: Downloading 1 format(s): 18
# [download] Destination: Data/videos/X16jagQdNIE.mp4
# [download] 100% of   25.14MiB in 00:00:07 at 3.35MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=igZ6PoZAszQ
# [youtube] igZ6PoZAszQ: Downloading webpage
# [youtube] igZ6PoZAszQ: Downloading tv client config
# [youtube] igZ6PoZAszQ: Downloading tv player API JSON
# [youtube] igZ6PoZAszQ: Downloading ios player API JSON
# [youtube] igZ6PoZAszQ: Downloading m3u8 information
# [info] igZ6PoZAszQ: Downloading 1 format(s): 18
# [download] Destination: Data/videos/igZ6PoZAszQ.mp4
# [download] 100% of   24.79MiB in 00:00:06 at 3.80MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RoDi72mL5sg
# [youtube] RoDi72mL5sg: Downloading webpage
# [youtube] RoDi72mL5sg: Downloading tv client config
# [youtube] RoDi72mL5sg: Downloading tv player API JSON
# [youtube] RoDi72mL5sg: Downloading ios player API JSON
# [youtube] RoDi72mL5sg: Downloading m3u8 information
# [info] RoDi72mL5sg: Downloading 1 format(s): 18
# [download] Destination: Data/videos/RoDi72mL5sg.mp4
# [download] 100% of   29.76MiB in 00:00:08 at 3.48MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4juSAp9jQjA
# [youtube] 4juSAp9jQjA: Downloading webpage
# [youtube] 4juSAp9jQjA: Downloading tv client config
# [youtube] 4juSAp9jQjA: Downloading tv player API JSON
# [youtube] 4juSAp9jQjA: Downloading ios player API JSON
# [youtube] 4juSAp9jQjA: Downloading m3u8 information
# [info] 4juSAp9jQjA: Downloading 1 format(s): 18
# [download] Destination: Data/videos/4juSAp9jQjA.mp4
# [download] 100% of   35.14MiB in 00:00:08 at 4.10MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oED9tZyI-vU
# [youtube] oED9tZyI-vU: Downloading webpage
# [youtube] oED9tZyI-vU: Downloading tv client config
# [youtube] oED9tZyI-vU: Downloading tv player API JSON
# [youtube] oED9tZyI-vU: Downloading ios player API JSON
# [youtube] oED9tZyI-vU: Downloading m3u8 information
# [info] oED9tZyI-vU: Downloading 1 format(s): 18
# [download] Destination: Data/videos/oED9tZyI-vU.mp4
# [download]   1.0% of   50.61MiB at    2.45MiB/s ETA 00:20

# %% [markdown]
# ## Extract Frames from Videos files

# %%
def extract_frames(video_path, frame_output_dir, interval=2):
    cap = cv2.VideoCapture(str(video_path))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_interval = interval * fps
    count = 0

    success, image = cap.read()
    while success:
        if count % frame_interval == 0:
            frame_filename = frame_output_dir / f"{video_path.stem}_frame{count}.jpg"
            cv2.imwrite(str(frame_filename), image)
        success, image = cap.read()
        count += 1

    cap.release()
    
    
# Run it for all videos
for video_file in VIDEO_DIR.glob("*.mp4"):
    extract_frames(video_file, FRAME_DIR)

# %% [markdown]
# # OpenCV's face Detector + DeepFace Emotion

# %%
# Load face detector once
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

results = []

for frame in tqdm(list(FRAME_DIR.glob("*.jpg"))):
    try:
        # Load image and convert to grayscale
        image = cv2.imread(str(frame))
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Face detection
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
        with_face = len(faces) > 0

        # Emotion analysis
        analysis = DeepFace.analyze(img_path=str(frame), actions=['emotion'], enforce_detection=False)
        emotion_scores = analysis[0]['emotion']

        # Frame info
        emotion_scores['frame'] = frame.name
        emotion_scores['video_id'] = frame.name.split("_frame")[0]
        emotion_scores['with_face'] = with_face

        # Visual features
        emotion_scores['brightness'] = gray.mean()
        emotion_scores['mean_r'] = image[:, :, 2].mean()
        emotion_scores['mean_g'] = image[:, :, 1].mean()
        emotion_scores['mean_b'] = image[:, :, 0].mean()
        emotion_scores['blurriness'] = cv2.Laplacian(gray, cv2.CV_64F).var()

        results.append(emotion_scores)

    except Exception as e:
        print(f"❌ Failed on {frame.name}: {e}")
# Out:
# 100%|██████████| 8993/8993 [08:22<00:00, 17.90it/s]

# %%
# Save full frame-level results
df_emotions = pd.DataFrame(results)
df_emotions.to_csv(RESULT_DIR / "frame_emotions.csv", index=False)

# %%
df_emotions.head()
# Out:
#           angry       disgust       fear      happy       sad      surprise  \
# 0  7.328841e-06  5.207927e-11  86.550062  13.449045  0.000589  2.955536e-04
# 1  6.482879e-07  4.164155e-10  68.873674   0.001573  0.704116  1.659583e-03
# 2  2.372728e-09  1.156472e-10   0.010090  99.958044  0.000033  1.003094e-10
# 3  1.133940e+01  4.657627e-02   1.807865   0.046684  0.541177  1.509955e+01
# 4  1.916571e-02  2.023292e-09   0.014573  98.256272  1.709994  5.815743e-10
#
#      neutral                       frame     video_id  with_face  brightness  \
# 0   0.000003   z1ywUmzOvQo_frame6072.jpg  z1ywUmzOvQo       True   99.639002
# 1  30.418977  eziSmP-ThWI_frame12374.jpg  eziSmP-ThWI       True   80.143433
# 2   0.031831  uy6MzxJSnWM_frame14076.jpg  uy6MzxJSnWM       True  109.082409
# 3  71.118742  NGStMwh0-TA_frame10580.jpg  NGStMwh0-TA      False  105.569970
# 4   0.000002  UCWfCrfLTc8_frame12144.jpg  UCWfCrfLTc8      False   79.803685
#
#        mean_r      mean_g      mean_b  blurriness
# 0  121.504961   93.514288   73.744865  537.975807
# 1   79.574392   79.348095   85.949857  522.181996
# 2  115.108893  105.508841  111.655434  627.049214
# 3  108.421441  104.328199  104.225768  105.266055
# 4   81.830664   79.372995   76.700751  479.315662

# %% [markdown]
# ## Emotional score for Frames with Face

# %%
# Define emotion columns
emotion_cols = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Only include frames where a face was detected
df_with_face = df_emotions[df_emotions['with_face'] == True]

# Compute video-level average (only on frames with faces)
df_avg = df_with_face.groupby("video_id")[emotion_cols].mean().reset_index()

# %% [markdown]
# ## Calculate the Percentage of with/ without face

# %%
face_stats = df_emotions.groupby("video_id").agg(
    total_frames=('frame', 'count'),
    face_frames=('with_face', 'sum')
).reset_index()

# Add percentage of frames with face
face_stats['pct_with_face'] = (face_stats['face_frames'] / face_stats['total_frames']) * 100

# %% [markdown]
# ## Calculate Visual Features

# %%
# Visual feature columns
visual_cols = ['brightness', 'mean_r', 'mean_g', 'mean_b', 'blurriness']

# Compute video-level mean across all frames (no face filtering)
visual_stats = df_emotions.groupby("video_id")[visual_cols].mean().reset_index()

# %% [markdown]
# ## Merge all Feature

# %%
# Merge emotion averages
combined_df = df_from_2020.merge(df_avg, on='video_id', how='left')

# Merge face detection stats
combined_df = combined_df.merge(face_stats[['video_id', 'pct_with_face']], on='video_id', how='left')

# Merge visual stats into combined_df
combined_df = combined_df.merge(visual_stats, on='video_id', how='left')

# Save as csv
combined_df.to_csv(RESULT_DIR / "video_metadata_with_emotions.csv", index=False)
combined_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Merge emotion averages
# ----> 2 combined_df = df_30vids.merge(df_avg, on='video_id', how='left')
#       4 # Merge face detection stats
#       5 combined_df = combined_df.merge(face_stats[['video_id', 'pct_with_face']], on='video_id', how='left')
#
# NameError: name 'df_30vids' is not defined

# %% [markdown]
# # EDA

# %%
combined_df = pd.read_csv("Data/results/video_metadata_with_emotions.csv")

# %%
# Distribution
cols = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral','pct_with_face']
combined_df[cols].hist(figsize=(12, 8), bins=20)
plt.suptitle("Feature Distribution")
plt.show()

# %%
# Correlation between emotions
sns.heatmap(combined_df[cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between each Features")
plt.show()

# %%
# Define metrics and feature columns
metrics = ["views", "likes", "comments"]
cols = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral','pct_with_face']

# Create a DataFrame to hold the correlations
correlation_df = pd.DataFrame(index=cols, columns=metrics)

# Fill in correlation values
for metric in metrics:
    for emotion in cols:
        correlation_df.at[emotion, metric] = combined_df[emotion].corr(combined_df[metric])

# Convert values to float type
correlation_df = correlation_df.astype(float)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_df, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Between Emotions and Video Engagement")
plt.show()

# %% [markdown]
# # Regression Analysis

# %%
import numpy as np
import statsmodels.api as sm
import re

df_model = combined_df.copy()
df_model['logviews'] = np.log(df_model['views'])

emotion_cols = ['angry','disgust','fear','happy','sad','surprise','neutral']

X = df_model[emotion_cols]
X = sm.add_constant(X)

# model including only neutral score -> negative impact indicates that emotions generally seem to improve view count
X = df_model['neutral']
X = sm.add_constant(X)
y = df_model['logviews']
model = sm.OLS(y,X).fit()
print('Linear Model Views ~ Neutral Emotion Score: \n', model.summary())
